# %%
# %matplotlib inline
from train_nf import train_nf
import numpy as np
from scipy.stats import dirichlet
from tf_util.families import family_from_str
from efn_util import model_opt_hps
import os, sys
from dirichlet import simplex
import matplotlib.pyplot as plt

os.chdir('../../');
# Out:
# /Users/sbittner/Library/Python/3.6/lib/python/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
exp_fam = 'dirichlet';
D = 4;
nlayers = 2;
give_inverse_hint = False;
dist_seed = 0;
dir_str = 'bv_test';

TIF_flow_type, _, lr_order = model_opt_hps(exp_fam, D);

flow_dict = {'latent_dynamics':None, \
             'TIF_flow_type':TIF_flow_type, \
             'repeats':nlayers};

fam_class = family_from_str(exp_fam);
family = fam_class(D);

cost_type = 'KL';
M_eta = 1000;
min_iters = 20000;
max_iters = 20000;
check_rate = 100;

param_net_input_type = 'eta';  # I should generalize this draw_etas function to accept a None
np.random.seed(dist_seed);
eta, param_net_input, Tx_input, params = family.draw_etas(1, param_net_input_type, give_inverse_hint);
params = params[0];
params.update({'dist_seed':dist_seed});

alpha = params['alpha'];
print('alpha');
print(alpha);
dist = dirichlet(params['alpha']);
nsamps = 100;
X_true = dist.rvs(nsamps);
simplex.scatter(X_true)
plt.show()
# Out:
# alpha
# [2.96966077 3.71835215 3.21243519]

# %%
fontsize = 16;

for random_seed in range(10):
    log_p_zs, X, train_R2s, train_KLs, it = train_nf(family, params, flow_dict, cost_type, M_eta, lr_order, \
                                                     random_seed, min_iters, max_iters, check_rate, dir_str);
    plt.figure(figsize=(8,4));
    plt.subplot(1,2,1);
    simplex.scatter(X_true);
    plt.title('ground truth', fontsize=fontsize);
    plt.subplot(1,2,2);
    simplex.scatter(X[0,:100,:,0]);
    plt.title('trained NF', fontsize=fontsize);
    plt.show();
# Out:
# 0 <tf_util.flows.PlanarFlowLayer object at 0x127790b70>
# 1 <tf_util.flows.PlanarFlowLayer object at 0x127790ba8>
# 2 <tf_util.flows.PlanarFlowLayer object at 0x127790be0>
# params
# {'alpha': array([2.96966077, 3.71835215, 3.21243519]), 'dist_seed': 0}
# Tensor("Const_6:0", shape=(2, 1), dtype=float64)
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x12779eef0>
# Tensor("Const_7:0", shape=(1, 1), dtype=float64)
# Tensor("Const_8:0", shape=(2, 1), dtype=float64)
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x13310c470>
# Tensor("Const_9:0", shape=(1, 1), dtype=float64)
# Tensor("Const_10:0", shape=(2, 1), dtype=float64)
# <tensorflow.python.ops.init_ops.VarianceScaling object at 0x1080c4048>
# Tensor("Const_11:0", shape=(1, 1), dtype=float64)
# zshapes in
# connect flow
# (?, ?, 2, ?)
# 0 PlanarFlow_Layer1
# (?, ?, 2, ?)
# 1 PlanarFlow_Layer2
# (?, ?, 2, ?)
# 2 PlanarFlow_Layer3
# (?, ?, 2, ?)
# 3 SimplexBijectionLayer
# (?, ?, 3, ?)
# model entropy / true entropy
# -1.65E+00 / -1.30E+00
# saving summary 50
# model entropy / true entropy
# -1.38E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 100
# cost = 9.636691
# train elbo 9.601, train R2: 0.863, train KL 0.036
# iter 101 took 0.003528 seconds
# saving summary 100
# saving summary 150
# model entropy / true entropy
# -1.39E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 200
# cost = 9.583340
# train elbo 9.584, train R2: 0.924, train KL 0.018
# iter 201 took 0.003645 seconds
# saving summary 200
# saving summary 250
# model entropy / true entropy
# -1.35E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 300
# cost = 9.576590
# train elbo 9.588, train R2: 0.921, train KL 0.022
# iter 301 took 0.003536 seconds
# saving summary 300
# saving summary 350
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 400
# cost = 9.581644
# train elbo 9.589, train R2: 0.927, train KL 0.023
# iter 401 took 0.003338 seconds
# saving summary 400
# saving summary 450
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 500
# cost = 9.567444
# train elbo 9.597, train R2: 0.937, train KL 0.031
# iter 501 took 0.003442 seconds
# saving summary 500
# saving summary 550
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 600
# cost = 9.583134
# train elbo 9.580, train R2: 0.934, train KL 0.015
# iter 601 took 0.004018 seconds
# saving summary 600
# saving summary 650
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 700
# cost = 9.579144
# train elbo 9.584, train R2: 0.931, train KL 0.019
# iter 701 took 0.004231 seconds
# saving summary 700
# saving summary 750
# model entropy / true entropy
# -1.36E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 800
# cost = 9.574026
# train elbo 9.589, train R2: 0.931, train KL 0.023
# iter 801 took 0.003252 seconds
# saving summary 800
# saving summary 850
# model entropy / true entropy
# -1.36E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 900
# cost = 9.576360
# train elbo 9.581, train R2: 0.915, train KL 0.015
# iter 901 took 0.003741 seconds
# saving summary 900
# saving summary 950
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 1000
# cost = 9.581408
# train elbo 9.598, train R2: 0.939, train KL 0.032
# iter 1001 took 0.004071 seconds
# saving summary 1000
# saving summary 1050
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 1100
# cost = 9.580965
# train elbo 9.577, train R2: 0.937, train KL 0.011
# iter 1101 took 0.003714 seconds
# saving summary 1100
# saving summary 1150
# model entropy / true entropy
# -1.35E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 1200
# cost = 9.585090
# train elbo 9.582, train R2: 0.940, train KL 0.016
# iter 1201 took 0.003437 seconds
# saving summary 1200
# saving summary 1250
# model entropy / true entropy
# -1.35E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 1300
# cost = 9.579485
# train elbo 9.591, train R2: 0.949, train KL 0.025
# iter 1301 took 0.004652 seconds
# saving summary 1300
# saving summary 1350
# model entropy / true entropy
# -1.37E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 1400
# cost = 9.579332
# train elbo 9.583, train R2: 0.950, train KL 0.018
# iter 1401 took 0.003808 seconds
# saving summary 1400
# saving summary 1450
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 1500
# cost = 9.588825
# train elbo 9.580, train R2: 0.952, train KL 0.014
# iter 1501 took 0.004078 seconds
# saving summary 1500
# saving summary 1550
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 1600
# cost = 9.592070
# train elbo 9.572, train R2: 0.950, train KL 0.006
# iter 1601 took 0.003768 seconds
# saving summary 1600
# saving summary 1650
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 1700
# cost = 9.583714
# train elbo 9.575, train R2: 0.937, train KL 0.010
# iter 1701 took 0.003581 seconds
# saving summary 1700
# saving summary 1750
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 1800
# cost = 9.583832
# train elbo 9.571, train R2: 0.950, train KL 0.005
# iter 1801 took 0.003663 seconds
# saving summary 1800
# saving summary 1850
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 1900
# cost = 9.584401
# train elbo 9.583, train R2: 0.946, train KL 0.018
# iter 1901 took 0.004113 seconds
# saving summary 1900
# saving summary 1950
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 2000
# cost = 9.575618
# train elbo 9.578, train R2: 0.951, train KL 0.012
# iter 2001 took 0.003626 seconds
# saving summary 2000
# saving summary 2050
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 2100
# cost = 9.587496
# train elbo 9.582, train R2: 0.948, train KL 0.017
# iter 2101 took 0.003556 seconds
# saving summary 2100
# saving summary 2150
# model entropy / true entropy
# -1.36E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 2200
# cost = 9.576949
# train elbo 9.580, train R2: 0.956, train KL 0.015
# iter 2201 took 0.003824 seconds
# saving summary 2200
# saving summary 2250
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 2300
# cost = 9.579356
# train elbo 9.583, train R2: 0.952, train KL 0.017
# iter 2301 took 0.003311 seconds
# saving summary 2300
# saving summary 2350
# model entropy / true entropy
# -1.36E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 2400
# cost = 9.580591
# train elbo 9.571, train R2: 0.942, train KL 0.006
# iter 2401 took 0.003595 seconds
# saving summary 2400
# saving summary 2450
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 2500
# cost = 9.578702
# train elbo 9.577, train R2: 0.958, train KL 0.012
# iter 2501 took 0.003467 seconds
# saving summary 2500
# saving summary 2550
# model entropy / true entropy
# -1.36E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 2600
# cost = 9.576113
# train elbo 9.579, train R2: 0.954, train KL 0.014
# iter 2601 took 0.003899 seconds
# saving summary 2600
# saving summary 2650
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 2700
# cost = 9.587932
# train elbo 9.576, train R2: 0.954, train KL 0.011
# iter 2701 took 0.003612 seconds
# saving summary 2700
# saving summary 2750
# model entropy / true entropy
# -1.38E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 2800
# cost = 9.573989
# train elbo 9.579, train R2: 0.965, train KL 0.014
# iter 2801 took 0.003635 seconds
# saving summary 2800
# saving summary 2850
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 2900
# cost = 9.583703
# train elbo 9.576, train R2: 0.962, train KL 0.010
# iter 2901 took 0.003622 seconds
# saving summary 2900
# saving summary 2950
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 3000
# cost = 9.580700
# train elbo 9.569, train R2: 0.962, train KL 0.003
# iter 3001 took 0.003607 seconds
# saving summary 3000
# saving summary 3050
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 3100
# cost = 9.577343
# train elbo 9.582, train R2: 0.969, train KL 0.017
# iter 3101 took 0.003377 seconds
# saving summary 3100
# saving summary 3150
# model entropy / true entropy
# -1.28E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 3200
# cost = 9.573085
# train elbo 9.581, train R2: 0.968, train KL 0.015
# iter 3201 took 0.003450 seconds
# saving summary 3200
# saving summary 3250
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 3300
# cost = 9.574801
# train elbo 9.566, train R2: 0.958, train KL 0.001
# iter 3301 took 0.003594 seconds
# saving summary 3300
# saving summary 3350
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 3400
# cost = 9.574474
# train elbo 9.569, train R2: 0.976, train KL 0.003
# iter 3401 took 0.004014 seconds
# saving summary 3400
# saving summary 3450
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 3500
# cost = 9.572140
# train elbo 9.578, train R2: 0.977, train KL 0.013
# iter 3501 took 0.003619 seconds
# saving summary 3500
# saving summary 3550
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 3600
# cost = 9.573544
# train elbo 9.572, train R2: 0.986, train KL 0.007
# iter 3601 took 0.003455 seconds
# saving summary 3600
# saving summary 3650
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 3700
# cost = 9.575676
# train elbo 9.575, train R2: 0.982, train KL 0.009
# iter 3701 took 0.003746 seconds
# saving summary 3700
# saving summary 3750
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 3800
# cost = 9.574186
# train elbo 9.567, train R2: 0.986, train KL 0.002
# iter 3801 took 0.003886 seconds
# saving summary 3800
# saving summary 3850
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 3900
# cost = 9.572060
# train elbo 9.572, train R2: 0.986, train KL 0.007
# iter 3901 took 0.003698 seconds
# saving summary 3900
# saving summary 3950
# model entropy / true entropy
# -1.28E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 4000
# cost = 9.572597
# train elbo 9.568, train R2: 0.983, train KL 0.003
# iter 4001 took 0.003457 seconds
# saving summary 4000
# saving summary 4050
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 4100
# cost = 9.573477
# train elbo 9.571, train R2: 0.989, train KL 0.005
# iter 4101 took 0.003577 seconds
# saving summary 4100
# saving summary 4150
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 4200
# cost = 9.567456
# train elbo 9.568, train R2: 0.987, train KL 0.003
# iter 4201 took 0.003397 seconds
# saving summary 4200
# saving summary 4250
# model entropy / true entropy
# -1.25E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 4300
# cost = 9.569697
# train elbo 9.569, train R2: 0.989, train KL 0.003
# iter 4301 took 0.004121 seconds
# saving summary 4300
# saving summary 4350
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 4400
# cost = 9.567487
# train elbo 9.571, train R2: 0.979, train KL 0.006
# iter 4401 took 0.003721 seconds
# saving summary 4400
# saving summary 4450
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 4500
# cost = 9.570685
# train elbo 9.570, train R2: 0.990, train KL 0.004
# iter 4501 took 0.004191 seconds
# saving summary 4500
# saving summary 4550
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 4600
# cost = 9.573435
# train elbo 9.570, train R2: 0.989, train KL 0.005
# iter 4601 took 0.003484 seconds
# saving summary 4600
# saving summary 4650
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 4700
# cost = 9.568565
# train elbo 9.570, train R2: 0.991, train KL 0.004
# iter 4701 took 0.003846 seconds
# saving summary 4700
# saving summary 4750
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 4800
# cost = 9.570709
# train elbo 9.572, train R2: 0.987, train KL 0.006
# iter 4801 took 0.004024 seconds
# saving summary 4800
# saving summary 4850
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 4900
# cost = 9.567978
# train elbo 9.567, train R2: 0.991, train KL 0.002
# iter 4901 took 0.003512 seconds
# saving summary 4900
# saving summary 4950
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 5000
# cost = 9.565820
# train elbo 9.570, train R2: 0.991, train KL 0.004
# iter 5001 took 0.003565 seconds
# saving summary 5000
# saving summary 5050
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 5100
# cost = 9.568119
# train elbo 9.569, train R2: 0.990, train KL 0.004
# iter 5101 took 0.003757 seconds
# saving summary 5100
# saving summary 5150
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 5200
# cost = 9.568081
# train elbo 9.569, train R2: 0.991, train KL 0.004
# iter 5201 took 0.003537 seconds
# saving summary 5200
# saving summary 5250
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 5300
# cost = 9.568173
# train elbo 9.565, train R2: 0.991, train KL -0.000
# iter 5301 took 0.003310 seconds
# saving summary 5300
# saving summary 5350
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 5400
# cost = 9.571770
# train elbo 9.571, train R2: 0.992, train KL 0.005
# iter 5401 took 0.003461 seconds
# saving summary 5400
# saving summary 5450
# model entropy / true entropy
# -1.36E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 5500
# cost = 9.566370
# train elbo 9.568, train R2: 0.993, train KL 0.002
# iter 5501 took 0.003284 seconds
# saving summary 5500
# saving summary 5550
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 5600
# cost = 9.570054
# train elbo 9.569, train R2: 0.990, train KL 0.004
# iter 5601 took 0.003640 seconds
# saving summary 5600
# saving summary 5650
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 5700
# cost = 9.565332
# train elbo 9.572, train R2: 0.994, train KL 0.006
# iter 5701 took 0.003533 seconds
# saving summary 5700
# saving summary 5750
# model entropy / true entropy
# -1.26E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 5800
# cost = 9.567757
# train elbo 9.566, train R2: 0.990, train KL 0.000
# iter 5801 took 0.003261 seconds
# saving summary 5800
# saving summary 5850
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 5900
# cost = 9.568905
# train elbo 9.571, train R2: 0.991, train KL 0.005
# iter 5901 took 0.003591 seconds
# saving summary 5900
# saving summary 5950
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 6000
# cost = 9.567355
# train elbo 9.568, train R2: 0.992, train KL 0.002
# iter 6001 took 0.003953 seconds
# saving summary 6000
# saving summary 6050
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 6100
# cost = 9.571140
# train elbo 9.568, train R2: 0.991, train KL 0.003
# iter 6101 took 0.003644 seconds
# saving summary 6100
# saving summary 6150
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 6200
# cost = 9.572385
# train elbo 9.566, train R2: 0.989, train KL 0.001
# iter 6201 took 0.003679 seconds
# saving summary 6200
# saving summary 6250
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 6300
# cost = 9.568628
# train elbo 9.566, train R2: 0.990, train KL 0.001
# iter 6301 took 0.003789 seconds
# saving summary 6300
# saving summary 6350
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 6400
# cost = 9.569501
# train elbo 9.569, train R2: 0.993, train KL 0.004
# iter 6401 took 0.003983 seconds
# saving summary 6400
# saving summary 6450
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 6500
# cost = 9.568900
# train elbo 9.572, train R2: 0.993, train KL 0.006
# iter 6501 took 0.003556 seconds
# saving summary 6500
# saving summary 6550
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 6600
# cost = 9.566815
# train elbo 9.569, train R2: 0.994, train KL 0.003
# iter 6601 took 0.003520 seconds
# saving summary 6600
# saving summary 6650
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 6700
# cost = 9.570206
# train elbo 9.568, train R2: 0.993, train KL 0.003
# iter 6701 took 0.003483 seconds
# saving summary 6700
# saving summary 6750
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 6800
# cost = 9.569568
# train elbo 9.569, train R2: 0.992, train KL 0.003
# iter 6801 took 0.003791 seconds
# saving summary 6800
# saving summary 6850
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 6900
# cost = 9.568787
# train elbo 9.567, train R2: 0.992, train KL 0.002
# iter 6901 took 0.003759 seconds
# saving summary 6900
# saving summary 6950
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 7000
# cost = 9.569391
# train elbo 9.568, train R2: 0.995, train KL 0.002
# iter 7001 took 0.003708 seconds
# saving summary 7000
# saving summary 7050
# model entropy / true entropy
# -1.28E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 7100
# cost = 9.570152
# train elbo 9.564, train R2: 0.988, train KL -0.002
# iter 7101 took 0.003840 seconds
# saving summary 7100
# saving summary 7150
# model entropy / true entropy
# -1.25E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 7200
# cost = 9.567183
# train elbo 9.565, train R2: 0.992, train KL -0.001
# iter 7201 took 0.003584 seconds
# saving summary 7200
# saving summary 7250
# model entropy / true entropy
# -1.24E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 7300
# cost = 9.568549
# train elbo 9.569, train R2: 0.989, train KL 0.004
# iter 7301 took 0.003425 seconds
# saving summary 7300
# saving summary 7350
# model entropy / true entropy
# -1.27E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 7400
# cost = 9.569469
# train elbo 9.567, train R2: 0.994, train KL 0.002
# iter 7401 took 0.003643 seconds
# saving summary 7400
# saving summary 7450
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 7500
# cost = 9.567155
# train elbo 9.570, train R2: 0.995, train KL 0.005
# iter 7501 took 0.003631 seconds
# saving summary 7500
# saving summary 7550
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 7600
# cost = 9.569822
# train elbo 9.569, train R2: 0.994, train KL 0.003
# iter 7601 took 0.003570 seconds
# saving summary 7600
# saving summary 7650
# model entropy / true entropy
# -1.27E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 7700
# cost = 9.564599
# train elbo 9.564, train R2: 0.991, train KL -0.001
# iter 7701 took 0.003329 seconds
# saving summary 7700
# saving summary 7750
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 7800
# cost = 9.566365
# train elbo 9.569, train R2: 0.994, train KL 0.004
# iter 7801 took 0.003416 seconds
# saving summary 7800
# saving summary 7850
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 7900
# cost = 9.565907
# train elbo 9.565, train R2: 0.991, train KL -0.001
# iter 7901 took 0.003546 seconds
# saving summary 7900
# saving summary 7950
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 8000
# cost = 9.568606
# train elbo 9.570, train R2: 0.995, train KL 0.004
# iter 8001 took 0.003358 seconds
# saving summary 8000
# saving summary 8050
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 8100
# cost = 9.567416
# train elbo 9.564, train R2: 0.986, train KL -0.001
# iter 8101 took 0.003638 seconds
# saving summary 8100
# saving summary 8150
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 8200
# cost = 9.567240
# train elbo 9.563, train R2: 0.986, train KL -0.003
# iter 8201 took 0.003725 seconds
# saving summary 8200
# saving summary 8250
# model entropy / true entropy
# -1.35E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 8300
# cost = 9.569198
# train elbo 9.566, train R2: 0.995, train KL 0.000
# iter 8301 took 0.003426 seconds
# saving summary 8300
# saving summary 8350
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 8400
# cost = 9.567472
# train elbo 9.566, train R2: 0.993, train KL 0.001
# iter 8401 took 0.003370 seconds
# saving summary 8400
# saving summary 8450
# model entropy / true entropy
# -1.28E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 8500
# cost = 9.566340
# train elbo 9.569, train R2: 0.995, train KL 0.004
# iter 8501 took 0.003696 seconds
# saving summary 8500
# saving summary 8550
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 8600
# cost = 9.568676
# train elbo 9.566, train R2: 0.987, train KL 0.000
# iter 8601 took 0.003459 seconds
# saving summary 8600
# saving summary 8650
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 8700
# cost = 9.567269
# train elbo 9.567, train R2: 0.982, train KL 0.001
# iter 8701 took 0.003313 seconds
# saving summary 8700
# saving summary 8750
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 8800
# cost = 9.568936
# train elbo 9.570, train R2: 0.995, train KL 0.004
# iter 8801 took 0.003520 seconds
# saving summary 8800
# saving summary 8850
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 8900
# cost = 9.566280
# train elbo 9.569, train R2: 0.997, train KL 0.004
# iter 8901 took 0.004386 seconds
# saving summary 8900
# saving summary 8950
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 9000
# cost = 9.570365
# train elbo 9.568, train R2: 0.994, train KL 0.002
# iter 9001 took 0.003491 seconds
# saving summary 9000
# saving summary 9050
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 9100
# cost = 9.564119
# train elbo 9.564, train R2: 0.985, train KL -0.002
# iter 9101 took 0.003581 seconds
# saving summary 9100
# saving summary 9150
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 9200
# cost = 9.568314
# train elbo 9.566, train R2: 0.994, train KL 0.001
# iter 9201 took 0.003775 seconds
# saving summary 9200
# saving summary 9250
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 9300
# cost = 9.569034
# train elbo 9.565, train R2: 0.994, train KL -0.001
# iter 9301 took 0.003712 seconds
# saving summary 9300
# saving summary 9350
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 9400
# cost = 9.565193
# train elbo 9.564, train R2: 0.993, train KL -0.002
# iter 9401 took 0.003562 seconds
# saving summary 9400
# saving summary 9450
# model entropy / true entropy
# -1.35E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 9500
# cost = 9.567735
# train elbo 9.570, train R2: 0.993, train KL 0.004
# iter 9501 took 0.003563 seconds
# saving summary 9500
# saving summary 9550
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 9600
# cost = 9.569965
# train elbo 9.568, train R2: 0.996, train KL 0.002
# iter 9601 took 0.004188 seconds
# saving summary 9600
# saving summary 9650
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 9700
# cost = 9.568477
# train elbo 9.565, train R2: 0.992, train KL -0.001
# iter 9701 took 0.003717 seconds
# saving summary 9700
# saving summary 9750
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 9800
# cost = 9.563998
# train elbo 9.568, train R2: 0.993, train KL 0.003
# iter 9801 took 0.003184 seconds
# saving summary 9800
# saving summary 9850
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 9900
# cost = 9.569728
# train elbo 9.569, train R2: 0.996, train KL 0.003
# iter 9901 took 0.003437 seconds
# saving summary 9900
# saving summary 9950
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 10000
# cost = 9.562724
# train elbo 9.568, train R2: 0.994, train KL 0.002
# iter 10001 took 0.003575 seconds
# saving summary 10000
# saving summary 10050
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 10100
# cost = 9.567291
# train elbo 9.570, train R2: 0.996, train KL 0.004
# iter 10101 took 0.003527 seconds
# saving summary 10100
# saving summary 10150
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 10200
# cost = 9.565013
# train elbo 9.568, train R2: 0.996, train KL 0.002
# iter 10201 took 0.003382 seconds
# saving summary 10200
# saving summary 10250
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 10300
# cost = 9.566593
# train elbo 9.564, train R2: 0.994, train KL -0.001
# iter 10301 took 0.003473 seconds
# saving summary 10300
# saving summary 10350
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 10400
# cost = 9.567871
# train elbo 9.568, train R2: 0.995, train KL 0.003
# iter 10401 took 0.003883 seconds
# saving summary 10400
# saving summary 10450
# model entropy / true entropy
# -1.27E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 10500
# cost = 9.567217
# train elbo 9.567, train R2: 0.995, train KL 0.002
# iter 10501 took 0.003814 seconds
# saving summary 10500
# saving summary 10550
# model entropy / true entropy
# -1.28E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 10600
# cost = 9.569129
# train elbo 9.568, train R2: 0.994, train KL 0.002
# iter 10601 took 0.003425 seconds
# saving summary 10600
# saving summary 10650
# model entropy / true entropy
# -1.36E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 10700
# cost = 9.568137
# train elbo 9.566, train R2: 0.995, train KL 0.001
# iter 10701 took 0.003950 seconds
# saving summary 10700
# saving summary 10750
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 10800
# cost = 9.571258
# train elbo 9.569, train R2: 0.994, train KL 0.003
# iter 10801 took 0.003513 seconds
# saving summary 10800
# saving summary 10850
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 10900
# cost = 9.568455
# train elbo 9.565, train R2: 0.996, train KL -0.000
# iter 10901 took 0.003743 seconds
# saving summary 10900
# saving summary 10950
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 11000
# cost = 9.565159
# train elbo 9.568, train R2: 0.992, train KL 0.003
# iter 11001 took 0.003635 seconds
# saving summary 11000
# saving summary 11050
# model entropy / true entropy
# -1.26E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 11100
# cost = 9.566671
# train elbo 9.573, train R2: 0.995, train KL 0.007
# iter 11101 took 0.003478 seconds
# saving summary 11100
# saving summary 11150
# model entropy / true entropy
# -1.27E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 11200
# cost = 9.566219
# train elbo 9.563, train R2: 0.988, train KL -0.003
# iter 11201 took 0.003432 seconds
# saving summary 11200
# saving summary 11250
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 11300
# cost = 9.569817
# train elbo 9.568, train R2: 0.996, train KL 0.002
# iter 11301 took 0.003646 seconds
# saving summary 11300
# saving summary 11350
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 11400
# cost = 9.565581
# train elbo 9.569, train R2: 0.992, train KL 0.003
# iter 11401 took 0.003893 seconds
# saving summary 11400
# saving summary 11450
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 11500
# cost = 9.566812
# train elbo 9.568, train R2: 0.995, train KL 0.002
# iter 11501 took 0.003592 seconds
# saving summary 11500
# saving summary 11550
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 11600
# cost = 9.566482
# train elbo 9.567, train R2: 0.995, train KL 0.001
# iter 11601 took 0.003642 seconds
# saving summary 11600
# saving summary 11650
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 11700
# cost = 9.566663
# train elbo 9.568, train R2: 0.996, train KL 0.003
# iter 11701 took 0.003666 seconds
# saving summary 11700
# saving summary 11750
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 11800
# cost = 9.567635
# train elbo 9.566, train R2: 0.996, train KL 0.000
# iter 11801 took 0.003662 seconds
# saving summary 11800
# saving summary 11850
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 11900
# cost = 9.565607
# train elbo 9.567, train R2: 0.996, train KL 0.002
# iter 11901 took 0.003415 seconds
# saving summary 11900
# saving summary 11950
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 12000
# cost = 9.568339
# train elbo 9.568, train R2: 0.995, train KL 0.003
# iter 12001 took 0.003418 seconds
# saving summary 12000
# saving summary 12050
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 12100
# cost = 9.568789
# train elbo 9.567, train R2: 0.993, train KL 0.002
# iter 12101 took 0.003551 seconds
# saving summary 12100
# saving summary 12150
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 12200
# cost = 9.564813
# train elbo 9.566, train R2: 0.997, train KL 0.000
# iter 12201 took 0.003616 seconds
# saving summary 12200
# saving summary 12250
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 12300
# cost = 9.566800
# train elbo 9.568, train R2: 0.995, train KL 0.003
# iter 12301 took 0.003337 seconds
# saving summary 12300
# saving summary 12350
# model entropy / true entropy
# -1.28E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 12400
# cost = 9.569602
# train elbo 9.564, train R2: 0.993, train KL -0.002
# iter 12401 took 0.003558 seconds
# saving summary 12400
# saving summary 12450
# model entropy / true entropy
# -1.28E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 12500
# cost = 9.569408
# train elbo 9.569, train R2: 0.988, train KL 0.004
# iter 12501 took 0.003434 seconds
# saving summary 12500
# saving summary 12550
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 12600
# cost = 9.567823
# train elbo 9.567, train R2: 0.996, train KL 0.001
# iter 12601 took 0.003486 seconds
# saving summary 12600
# saving summary 12650
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 12700
# cost = 9.565972
# train elbo 9.571, train R2: 0.996, train KL 0.005
# iter 12701 took 0.003462 seconds
# saving summary 12700
# saving summary 12750
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 12800
# cost = 9.567379
# train elbo 9.567, train R2: 0.996, train KL 0.001
# iter 12801 took 0.003409 seconds
# saving summary 12800
# saving summary 12850
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 12900
# cost = 9.568597
# train elbo 9.567, train R2: 0.994, train KL 0.002
# iter 12901 took 0.003631 seconds
# saving summary 12900
# saving summary 12950
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 13000
# cost = 9.567369
# train elbo 9.568, train R2: 0.995, train KL 0.003
# iter 13001 took 0.003604 seconds
# saving summary 13000
# saving summary 13050
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 13100
# cost = 9.568966
# train elbo 9.569, train R2: 0.996, train KL 0.003
# iter 13101 took 0.003771 seconds
# saving summary 13100
# saving summary 13150
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 13200
# cost = 9.564802
# train elbo 9.565, train R2: 0.995, train KL 0.000
# iter 13201 took 0.003476 seconds
# saving summary 13200
# saving summary 13250
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 13300
# cost = 9.564003
# train elbo 9.570, train R2: 0.995, train KL 0.005
# iter 13301 took 0.003696 seconds
# saving summary 13300
# saving summary 13350
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 13400
# cost = 9.568206
# train elbo 9.567, train R2: 0.992, train KL 0.002
# iter 13401 took 0.003483 seconds
# saving summary 13400
# saving summary 13450
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 13500
# cost = 9.566285
# train elbo 9.568, train R2: 0.996, train KL 0.002
# iter 13501 took 0.003191 seconds
# saving summary 13500
# saving summary 13550
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 13600
# cost = 9.566000
# train elbo 9.569, train R2: 0.997, train KL 0.004
# iter 13601 took 0.003765 seconds
# saving summary 13600
# saving summary 13650
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 13700
# cost = 9.571910
# train elbo 9.567, train R2: 0.996, train KL 0.001
# iter 13701 took 0.003501 seconds
# saving summary 13700
# saving summary 13750
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 13800
# cost = 9.568196
# train elbo 9.568, train R2: 0.993, train KL 0.002
# iter 13801 took 0.003330 seconds
# saving summary 13800
# saving summary 13850
# model entropy / true entropy
# -1.27E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 13900
# cost = 9.567077
# train elbo 9.567, train R2: 0.995, train KL 0.002
# iter 13901 took 0.003371 seconds
# saving summary 13900
# saving summary 13950
# model entropy / true entropy
# -1.35E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 14000
# cost = 9.569276
# train elbo 9.568, train R2: 0.996, train KL 0.002
# iter 14001 took 0.003627 seconds
# saving summary 14000
# saving summary 14050
# model entropy / true entropy
# -1.27E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 14100
# cost = 9.566338
# train elbo 9.566, train R2: 0.996, train KL 0.000
# iter 14101 took 0.003661 seconds
# saving summary 14100
# saving summary 14150
# model entropy / true entropy
# -1.36E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 14200
# cost = 9.568073
# train elbo 9.570, train R2: 0.995, train KL 0.005
# iter 14201 took 0.003547 seconds
# saving summary 14200
# saving summary 14250
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 14300
# cost = 9.567496
# train elbo 9.568, train R2: 0.995, train KL 0.003
# iter 14301 took 0.003684 seconds
# saving summary 14300
# saving summary 14350
# model entropy / true entropy
# -1.27E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 14400
# cost = 9.568315
# train elbo 9.565, train R2: 0.995, train KL -0.000
# iter 14401 took 0.003663 seconds
# saving summary 14400
# saving summary 14450
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 14500
# cost = 9.564205
# train elbo 9.566, train R2: 0.997, train KL 0.000
# iter 14501 took 0.003635 seconds
# saving summary 14500
# saving summary 14550
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 14600
# cost = 9.568498
# train elbo 9.567, train R2: 0.995, train KL 0.002
# iter 14601 took 0.003641 seconds
# saving summary 14600
# saving summary 14650
# model entropy / true entropy
# -1.27E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 14700
# cost = 9.567550
# train elbo 9.566, train R2: 0.996, train KL 0.000
# iter 14701 took 0.003865 seconds
# saving summary 14700
# saving summary 14750
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 14800
# cost = 9.566147
# train elbo 9.569, train R2: 0.996, train KL 0.003
# iter 14801 took 0.003730 seconds
# saving summary 14800
# saving summary 14850
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 14900
# cost = 9.567203
# train elbo 9.566, train R2: 0.995, train KL 0.000
# iter 14901 took 0.003613 seconds
# saving summary 14900
# saving summary 14950
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 15000
# cost = 9.566295
# train elbo 9.567, train R2: 0.997, train KL 0.002
# iter 15001 took 0.003475 seconds
# saving summary 15000
# saving summary 15050
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 15100
# cost = 9.566044
# train elbo 9.567, train R2: 0.996, train KL 0.001
# iter 15101 took 0.003602 seconds
# saving summary 15100
# saving summary 15150
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 15200
# cost = 9.567397
# train elbo 9.566, train R2: 0.997, train KL 0.001
# iter 15201 took 0.003394 seconds
# saving summary 15200
# saving summary 15250
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 15300
# cost = 9.569005
# train elbo 9.565, train R2: 0.996, train KL -0.001
# iter 15301 took 0.003383 seconds
# saving summary 15300
# saving summary 15350
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 15400
# cost = 9.569604
# train elbo 9.565, train R2: 0.996, train KL -0.001
# iter 15401 took 0.003424 seconds
# saving summary 15400
# saving summary 15450
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 15500
# cost = 9.566002
# train elbo 9.567, train R2: 0.998, train KL 0.002
# iter 15501 took 0.003825 seconds
# saving summary 15500
# saving summary 15550
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 15600
# cost = 9.567121
# train elbo 9.566, train R2: 0.996, train KL 0.001
# iter 15601 took 0.003664 seconds
# saving summary 15600
# saving summary 15650
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 15700
# cost = 9.566843
# train elbo 9.567, train R2: 0.994, train KL 0.002
# iter 15701 took 0.003454 seconds
# saving summary 15700
# saving summary 15750
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=0/
# it = 15800
# ...
# iter 14701 took 0.004965 seconds
# saving summary 14700
# saving summary 14750
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 14800
# cost = 9.569027
# train elbo 9.569, train R2: 0.993, train KL 0.003
# iter 14801 took 0.004036 seconds
# saving summary 14800
# saving summary 14850
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 14900
# cost = 9.567655
# train elbo 9.567, train R2: 0.995, train KL 0.001
# iter 14901 took 0.004211 seconds
# saving summary 14900
# saving summary 14950
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 15000
# cost = 9.567281
# train elbo 9.568, train R2: 0.995, train KL 0.002
# iter 15001 took 0.004436 seconds
# saving summary 15000
# saving summary 15050
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 15100
# cost = 9.567252
# train elbo 9.569, train R2: 0.995, train KL 0.004
# iter 15101 took 0.004294 seconds
# saving summary 15100
# saving summary 15150
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 15200
# cost = 9.566597
# train elbo 9.566, train R2: 0.995, train KL 0.001
# iter 15201 took 0.004052 seconds
# saving summary 15200
# saving summary 15250
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 15300
# cost = 9.570315
# train elbo 9.566, train R2: 0.995, train KL 0.001
# iter 15301 took 0.004188 seconds
# saving summary 15300
# saving summary 15350
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 15400
# cost = 9.569522
# train elbo 9.566, train R2: 0.994, train KL 0.000
# iter 15401 took 0.004151 seconds
# saving summary 15400
# saving summary 15450
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 15500
# cost = 9.565163
# train elbo 9.567, train R2: 0.996, train KL 0.001
# iter 15501 took 0.004117 seconds
# saving summary 15500
# saving summary 15550
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 15600
# cost = 9.567356
# train elbo 9.566, train R2: 0.995, train KL 0.001
# iter 15601 took 0.004052 seconds
# saving summary 15600
# saving summary 15650
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 15700
# cost = 9.566981
# train elbo 9.568, train R2: 0.994, train KL 0.003
# iter 15701 took 0.004630 seconds
# saving summary 15700
# saving summary 15750
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 15800
# cost = 9.566023
# train elbo 9.569, train R2: 0.992, train KL 0.003
# iter 15801 took 0.004145 seconds
# saving summary 15800
# saving summary 15850
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 15900
# cost = 9.566586
# train elbo 9.567, train R2: 0.994, train KL 0.002
# iter 15901 took 0.003625 seconds
# saving summary 15900
# saving summary 15950
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 16000
# cost = 9.569445
# train elbo 9.569, train R2: 0.993, train KL 0.004
# iter 16001 took 0.004452 seconds
# saving summary 16000
# saving summary 16050
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 16100
# cost = 9.566159
# train elbo 9.566, train R2: 0.992, train KL 0.000
# iter 16101 took 0.003674 seconds
# saving summary 16100
# saving summary 16150
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 16200
# cost = 9.567058
# train elbo 9.565, train R2: 0.990, train KL -0.001
# iter 16201 took 0.004550 seconds
# saving summary 16200
# saving summary 16250
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 16300
# cost = 9.565292
# train elbo 9.569, train R2: 0.995, train KL 0.003
# iter 16301 took 0.004067 seconds
# saving summary 16300
# saving summary 16350
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 16400
# cost = 9.568166
# train elbo 9.565, train R2: 0.993, train KL -0.001
# iter 16401 took 0.005445 seconds
# saving summary 16400
# saving summary 16450
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 16500
# cost = 9.566446
# train elbo 9.566, train R2: 0.992, train KL 0.001
# iter 16501 took 0.005904 seconds
# saving summary 16500
# saving summary 16550
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 16600
# cost = 9.566969
# train elbo 9.567, train R2: 0.996, train KL 0.002
# iter 16601 took 0.005722 seconds
# saving summary 16600
# saving summary 16650
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 16700
# cost = 9.566817
# train elbo 9.565, train R2: 0.992, train KL -0.001
# iter 16701 took 0.004991 seconds
# saving summary 16700
# saving summary 16750
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 16800
# cost = 9.566731
# train elbo 9.566, train R2: 0.996, train KL 0.001
# iter 16801 took 0.004896 seconds
# saving summary 16800
# saving summary 16850
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 16900
# cost = 9.566276
# train elbo 9.567, train R2: 0.995, train KL 0.002
# iter 16901 took 0.005757 seconds
# saving summary 16900
# saving summary 16950
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 17000
# cost = 9.567223
# train elbo 9.568, train R2: 0.996, train KL 0.003
# iter 17001 took 0.004349 seconds
# saving summary 17000
# saving summary 17050
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 17100
# cost = 9.565605
# train elbo 9.568, train R2: 0.993, train KL 0.002
# iter 17101 took 0.005857 seconds
# saving summary 17100
# saving summary 17150
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 17200
# cost = 9.569885
# train elbo 9.568, train R2: 0.996, train KL 0.003
# iter 17201 took 0.004912 seconds
# saving summary 17200
# saving summary 17250
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 17300
# cost = 9.570133
# train elbo 9.566, train R2: 0.987, train KL 0.000
# iter 17301 took 0.004847 seconds
# saving summary 17300
# saving summary 17350
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 17400
# cost = 9.563308
# train elbo 9.567, train R2: 0.996, train KL 0.002
# iter 17401 took 0.005070 seconds
# saving summary 17400
# saving summary 17450
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 17500
# cost = 9.566488
# train elbo 9.563, train R2: 0.995, train KL -0.002
# iter 17501 took 0.003711 seconds
# saving summary 17500
# saving summary 17550
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 17600
# cost = 9.567723
# train elbo 9.566, train R2: 0.994, train KL 0.000
# iter 17601 took 0.005038 seconds
# saving summary 17600
# saving summary 17650
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 17700
# cost = 9.567944
# train elbo 9.564, train R2: 0.991, train KL -0.001
# iter 17701 took 0.003543 seconds
# saving summary 17700
# saving summary 17750
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 17800
# cost = 9.566704
# train elbo 9.566, train R2: 0.995, train KL 0.001
# iter 17801 took 0.003926 seconds
# saving summary 17800
# saving summary 17850
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 17900
# cost = 9.570405
# train elbo 9.568, train R2: 0.995, train KL 0.003
# iter 17901 took 0.003606 seconds
# saving summary 17900
# saving summary 17950
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 18000
# cost = 9.567826
# train elbo 9.565, train R2: 0.992, train KL 0.000
# iter 18001 took 0.003752 seconds
# saving summary 18000
# saving summary 18050
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 18100
# cost = 9.567887
# train elbo 9.570, train R2: 0.995, train KL 0.005
# iter 18101 took 0.005061 seconds
# saving summary 18100
# saving summary 18150
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 18200
# cost = 9.567673
# train elbo 9.566, train R2: 0.994, train KL 0.000
# iter 18201 took 0.004954 seconds
# saving summary 18200
# saving summary 18250
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 18300
# cost = 9.569260
# train elbo 9.566, train R2: 0.992, train KL 0.001
# iter 18301 took 0.005026 seconds
# saving summary 18300
# saving summary 18350
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 18400
# cost = 9.569486
# train elbo 9.568, train R2: 0.996, train KL 0.003
# iter 18401 took 0.006038 seconds
# saving summary 18400
# saving summary 18450
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 18500
# cost = 9.567730
# train elbo 9.566, train R2: 0.994, train KL 0.000
# iter 18501 took 0.005214 seconds
# saving summary 18500
# saving summary 18550
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 18600
# cost = 9.565781
# train elbo 9.568, train R2: 0.995, train KL 0.002
# iter 18601 took 0.004436 seconds
# saving summary 18600
# saving summary 18650
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 18700
# cost = 9.568315
# train elbo 9.568, train R2: 0.995, train KL 0.003
# iter 18701 took 0.005884 seconds
# saving summary 18700
# saving summary 18750
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 18800
# cost = 9.569916
# train elbo 9.568, train R2: 0.994, train KL 0.002
# iter 18801 took 0.005435 seconds
# saving summary 18800
# saving summary 18850
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 18900
# cost = 9.566729
# train elbo 9.566, train R2: 0.994, train KL 0.001
# iter 18901 took 0.004989 seconds
# saving summary 18900
# saving summary 18950
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 19000
# cost = 9.567941
# train elbo 9.569, train R2: 0.994, train KL 0.003
# iter 19001 took 0.003999 seconds
# saving summary 19000
# saving summary 19050
# model entropy / true entropy
# -1.33E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 19100
# cost = 9.567241
# train elbo 9.567, train R2: 0.994, train KL 0.001
# iter 19101 took 0.004443 seconds
# saving summary 19100
# saving summary 19150
# model entropy / true entropy
# -1.32E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 19200
# cost = 9.565909
# train elbo 9.568, train R2: 0.997, train KL 0.003
# iter 19201 took 0.004911 seconds
# saving summary 19200
# saving summary 19250
# model entropy / true entropy
# -1.28E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 19300
# cost = 9.568154
# train elbo 9.565, train R2: 0.993, train KL -0.000
# iter 19301 took 0.005178 seconds
# saving summary 19300
# saving summary 19350
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 19400
# cost = 9.565043
# train elbo 9.568, train R2: 0.993, train KL 0.003
# iter 19401 took 0.004552 seconds
# saving summary 19400
# saving summary 19450
# model entropy / true entropy
# -1.34E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 19500
# cost = 9.566110
# train elbo 9.567, train R2: 0.994, train KL 0.001
# iter 19501 took 0.004168 seconds
# saving summary 19500
# saving summary 19550
# model entropy / true entropy
# -1.28E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 19600
# cost = 9.565630
# train elbo 9.565, train R2: 0.988, train KL -0.000
# iter 19601 took 0.004861 seconds
# saving summary 19600
# saving summary 19650
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 19700
# cost = 9.567332
# train elbo 9.569, train R2: 0.996, train KL 0.004
# iter 19701 took 0.004824 seconds
# saving summary 19700
# saving summary 19750
# model entropy / true entropy
# -1.31E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 19800
# cost = 9.568509
# train elbo 9.570, train R2: 0.996, train KL 0.004
# iter 19801 took 0.004704 seconds
# saving summary 19800
# saving summary 19850
# model entropy / true entropy
# -1.29E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 19900
# cost = 9.568050
# train elbo 9.566, train R2: 0.995, train KL 0.001
# iter 19901 took 0.004869 seconds
# saving summary 19900
# saving summary 19950
# saving model at iter 19999
# model entropy / true entropy
# -1.30E+00 / -1.30E+00
# ******************************************
# results/bv_test/NF1_dirichlet_D=3_flow=3P_ds=0_rs=9/
# it = 20000
# cost = 9.567240
# train elbo 9.571, train R2: 0.994, train KL 0.006
