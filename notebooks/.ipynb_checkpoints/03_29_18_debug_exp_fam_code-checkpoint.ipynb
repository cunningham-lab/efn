# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fname = 'debug.npz';
file = np.load(fname);

y = file['y'];
Tx = file['Tx'];
eta = file['eta'];
X = file['X'][:,:,0];
Z0 = file['Z0'];
print(y.shape);

n = X.shape[0];
sizes = 40*np.ones((n,1));

plt.figure();
plt.scatter(Z0[:,0], Z0[:,1], sizes, y[:,0]);
plt.colorbar();
plt.show();

plt.figure();
plt.scatter(X[:,0], X[:,1], sizes, y[:,0]);
plt.colorbar();
plt.show();

alpha = np.mean(y - np.dot(Tx, eta));

y_pred = np.dot(Tx, eta) + alpha;

print(y.shape, Tx.shape, eta.shape, alpha.shape);
residuals = y - np.dot(Tx, eta) - alpha;
print(residuals.shape);
plt.figure();
plt.stem(residuals);
plt.show();
# Out:
# (200, 200) (200, 6) (6, 1) ()
# (200, 200)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-93873bea9c45> in <module>()
#      33 print(residuals.shape);
#      34 plt.figure();
# ---> 35 plt.stem(residuals);
#      36 plt.show();
#
# ~/Library/Python/3.6/lib/python/site-packages/matplotlib/pyplot.py in stem(*args, **kwargs)
#    3544                       mplDeprecation)
#    3545     try:
# -> 3546         ret = ax.stem(*args, **kwargs)
#    3547     finally:
#    3548         ax._hold = washold
#
# ~/Library/Python/3.6/lib/python/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# ~/Library/Python/3.6/lib/python/site-packages/matplotlib/axes/_axes.py in stem(self, *args, **kwargs)
#    2444
#    2445         markerline, = self.plot(x, y, color=markercolor, linestyle=markerstyle,
# -> 2446                                 marker=markermarker, label="_nolegend_")
#    2447
#    2448         if bottom is None:
#
# ValueError: too many values to unpack (expected 1)
